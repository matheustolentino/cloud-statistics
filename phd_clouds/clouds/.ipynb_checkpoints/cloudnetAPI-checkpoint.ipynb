# %%
import requests

url = 'https://cloudnet.fmi.fi/api/files'
payload = {
    'date': '2020-10-01',
    'product': 'classification',
    'site': 'granada',
    'instrument': 'radar'
}
metadata = requests.get(url, payload).json()
for row in metadata:
    res = requests.get(row['downloadUrl'])
    with open(row['filename'], 'wb') as f:
        f.write(res.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 12
#      10 metadata = requests.get(url, payload).json()
#      11 for row in metadata:
# ---> 12     res = requests.get(row['downloadUrl'])
#      13     with open(row['filename'], 'wb') as f:
#      14         f.write(res.content)
#
# TypeError: string indices must be integers
